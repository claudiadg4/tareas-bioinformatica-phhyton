# %% [markdown]
# Mi primer notebook

# %% [markdown]
# este es mi primer notebook y voy hace rlo siguiente

# %% [markdown]
# 1. primero
# 2. segundo
# 3. tercero

# %% [markdown]
# * primero
# * segundo
# * tercero

# %% [markdown]
# mi primer codigo

# %%
mi_primera_frase="hello world"

# %%
print(mi_primera_frase)
# Out:
# hello world

# %%
numeros= [10,20,30,40,50]

# %%
media=sum(numeros)/len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# ![Mi imagen](fotomurales-puesta-de-sol-en-la-playa.png)
